# %%
import geopandas as gpd

# %%
moisture_df = gpd.read_file('data/field4/Moisture.shp')
dry_yield_df = gpd.read_file('data/field4/DryYield.shp')
speed_df = gpd.read_file('data/field4/Speed.shp')
width_df = gpd.read_file('data/field4/Width.shp')
df = gpd.read_file('data/field4/SmartFarmDemoField 04_2021.shp')

# %%
moisture_df = moisture_df.set_geometry('geometry')
dry_yield_df = dry_yield_df.set_geometry('geometry')
speed_df = speed_df.set_geometry('geometry')
width_df = width_df.set_geometry('geometry')
df = df.set_geometry('geometry')

# %%
df
# Out:
#                        Name               Client        Farm  Year  \
# 0  Smart Farm Demo Field 04  Area X O Smart Farm  Smart Farm  2021
#
#                                             geometry
# 0  POLYGON Z ((-75.75784 45.32244 0.00000, -75.75...

# %%
moisture_df
# Out:
#      Name   Moisture Units                 Time                    geometry
# 0     NaN  22.299999     %  2021-11-06T23:21:11  POINT (-75.75701 45.32174)
# 1     NaN  24.900000     %  2021-11-06T23:21:12  POINT (-75.75700 45.32174)
# 2     NaN  23.100000     %  2021-11-06T23:21:13  POINT (-75.75700 45.32174)
# 3     NaN  22.600000     %  2021-11-06T23:21:14  POINT (-75.75699 45.32174)
# 4     NaN  22.500000     %  2021-11-06T23:21:15  POINT (-75.75699 45.32175)
# ..    ...        ...   ...                  ...                         ...
# 868   NaN  22.500000     %  2021-11-06T23:40:21  POINT (-75.75680 45.32194)
# 869   NaN  22.500000     %  2021-11-06T23:40:22  POINT (-75.75678 45.32193)
# 870   NaN  22.500000     %  2021-11-06T23:40:23  POINT (-75.75676 45.32193)
# 871   NaN  22.500000     %  2021-11-06T23:40:24  POINT (-75.75674 45.32192)
# 872   NaN  22.500000     %  2021-11-06T23:40:25  POINT (-75.75672 45.32192)
#
# [873 rows x 5 columns]

# %%
speed_df
# Out:
#      Name     Speed Units                 Time                    geometry
# 0     NaN  1.050000   mph  2021-11-06T23:21:11  POINT (-75.75701 45.32174)
# 1     NaN  1.009091   mph  2021-11-06T23:21:12  POINT (-75.75700 45.32174)
# 2     NaN  0.981818   mph  2021-11-06T23:21:13  POINT (-75.75700 45.32174)
# 3     NaN  0.961364   mph  2021-11-06T23:21:14  POINT (-75.75699 45.32174)
# 4     NaN  0.961364   mph  2021-11-06T23:21:15  POINT (-75.75699 45.32175)
# ..    ...       ...   ...                  ...                         ...
# 868   NaN  4.118182   mph  2021-11-06T23:40:21  POINT (-75.75680 45.32194)
# 869   NaN  4.050000   mph  2021-11-06T23:40:22  POINT (-75.75678 45.32193)
# 870   NaN  4.002273   mph  2021-11-06T23:40:23  POINT (-75.75676 45.32193)
# 871   NaN  3.579545   mph  2021-11-06T23:40:24  POINT (-75.75674 45.32192)
# 872   NaN  2.256818   mph  2021-11-06T23:40:25  POINT (-75.75672 45.32192)
#
# [873 rows x 5 columns]

# %%
dry_yield_df
# Out:
#      Name   DryYield  Units                 Time                    geometry
# 0     NaN   4.644207  bu/ac  2021-11-06T23:21:11  POINT (-75.75701 45.32174)
# 1     NaN  11.676952  bu/ac  2021-11-06T23:21:12  POINT (-75.75700 45.32174)
# 2     NaN  19.662336  bu/ac  2021-11-06T23:21:13  POINT (-75.75700 45.32174)
# 3     NaN  27.790466  bu/ac  2021-11-06T23:21:14  POINT (-75.75699 45.32174)
# 4     NaN  32.885712  bu/ac  2021-11-06T23:21:15  POINT (-75.75699 45.32175)
# ..    ...        ...    ...                  ...                         ...
# 868   NaN  37.888950  bu/ac  2021-11-06T23:40:21  POINT (-75.75680 45.32194)
# 869   NaN  38.526814  bu/ac  2021-11-06T23:40:22  POINT (-75.75678 45.32193)
# 870   NaN  34.112965  bu/ac  2021-11-06T23:40:23  POINT (-75.75676 45.32193)
# 871   NaN  32.692753  bu/ac  2021-11-06T23:40:24  POINT (-75.75674 45.32192)
# 872   NaN  47.532890  bu/ac  2021-11-06T23:40:25  POINT (-75.75672 45.32192)
#
# [873 rows x 5 columns]

# %%
width_df
# Out:
#      Name  Width Units                 Time                    geometry
# 0     NaN  20.01    ft  2021-11-06T23:21:11  POINT (-75.75701 45.32174)
# 1     NaN  20.01    ft  2021-11-06T23:21:12  POINT (-75.75700 45.32174)
# 2     NaN  20.01    ft  2021-11-06T23:21:13  POINT (-75.75700 45.32174)
# 3     NaN  20.01    ft  2021-11-06T23:21:14  POINT (-75.75699 45.32174)
# 4     NaN  20.01    ft  2021-11-06T23:21:15  POINT (-75.75699 45.32175)
# ..    ...    ...   ...                  ...                         ...
# 868   NaN   4.99    ft  2021-11-06T23:40:21  POINT (-75.75680 45.32194)
# 869   NaN   4.99    ft  2021-11-06T23:40:22  POINT (-75.75678 45.32193)
# 870   NaN   4.99    ft  2021-11-06T23:40:23  POINT (-75.75676 45.32193)
# 871   NaN   4.99    ft  2021-11-06T23:40:24  POINT (-75.75674 45.32192)
# 872   NaN   4.99    ft  2021-11-06T23:40:25  POINT (-75.75672 45.32192)
#
# [873 rows x 5 columns]

# %%
dry_yield_df.plot()
# Out:
# <AxesSubplot: >
